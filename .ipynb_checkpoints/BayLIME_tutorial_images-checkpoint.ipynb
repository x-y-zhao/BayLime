# %% [markdown]
# ## This is a quick tutorial on how to use BayLIME to explain an image.
#
# by XZ 05/10/2020

# %%
import os
import tensorflow as tf
from tensorflow import keras
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
import numpy as np
from skimage.segmentation import mark_boundaries
from lime import lime_image
import csv
from lime import calculate_posteriors
print('Notebook run using keras:', keras.__version__)
# Out:
# Using TensorFlow backend.
# Notebook run using keras: 2.2.4-tf

# %% [markdown]
# Same as the original LIME tutorial, we are reusing the pretrained DNN InceptionV3.

# %%
#Same as the original LIME tutorial,
#here we create a standard InceptionV3 pretrained model 
#and use it on images by first preprocessing them with the preprocessing tools
inet_model = inc_net.InceptionV3()

def transform_img_fn(path_list):
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=(299, 299))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = inc_net.preprocess_input(x)
        out.append(x)
    return np.vstack(out)


images = transform_img_fn([os.path.join('data','5.jpg')])
# I'm dividing by 2 and adding 0.5 because of
# how this Inception represents images
plt.imshow(images[0] / 2 + 0.5)
plt.show()
preds = inet_model.predict(images)
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# ('n02099601', 'golden_retriever', 0.7591777)
# ('n02099712', 'Labrador_retriever', 0.13248245)
# ('n02102318', 'cocker_spaniel', 0.015283059)
# ('n02101556', 'clumber', 0.014689475)
# ('n02104029', 'kuvasz', 0.0038136626)

# %% [markdown]
# #### Now we create an instance of LIME explainer with an arg _feature_selection='none'_ meaning we will consider all features of the image in our later explanation. You may also specify other args like kernel_width etc. For a complete list of args, cf. the comments in the sources code when defining the class.

# %%
explainer = lime_image.LimeImageExplainer(feature_selection='none')#kernel_width=0.1

# %% [markdown]
# #### First, let us explain the image _image[0]_ with the original LIME -- i.e. with option _model_regressor='non_Bay'_ .
#
# Meanings behind other args, again, can be found in comments of the source codes when defining the function. E.g., _number_samples=200_ represents the number of perturbed samples used for the training of the local surrogate model.

# %%
explanation = explainer.explain_instance(images[0], inet_model.predict,
                                         top_labels=3, hide_color=0, batch_size=10,
                                         num_samples=200,model_regressor='non_Bay')
#'non_Bay' 'Bay_non_info_prior' 'Bay_info_prior','BayesianRidge_inf_prior_fit_alpha'
# Out:
# the number of features: 63
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# using non_Bay option for model regressor
# using non_Bay option for model regressor
# using non_Bay option for model regressor

# %% [markdown]
# Now we have done the explanations for the top 3 labels. We have different ways to present the explanation results -- to show a few regarding the top label as the following:
# 1. Showing top 10 features and hide the rest. Also the 10 features could have both positive and negative contribution to the prediction.
# 2. Only showing the top 5 positive features without hiding the rest.
# 3. Or we can simply present the 'importance' of each feature as a list.
#
# Note, the mean and variance information for the top 10 features are internal assertions that can be switched off (assuming they are repetitive in some cases). In this case, since we are using non-bay option, there is no mean/variance actually, so you see a 0 variance and mean really represents the fitted coefficient by the Linear Regressor.

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
plt.show()

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
plt.show()

print(explanation.as_list(explanation.top_labels[0]))
# Out:
# For feature of segment 36
# The mean of the (posterior) coefficient 0.13613138893679472
# The variance of the (posterior) coefficient 0.0
# For feature of segment 34
# The mean of the (posterior) coefficient 0.0665519094667804
# The variance of the (posterior) coefficient 0.0
# For feature of segment 47
# The mean of the (posterior) coefficient 0.06212260387143467
# The variance of the (posterior) coefficient 0.0
# For feature of segment 29
# The mean of the (posterior) coefficient 0.06056040233091802
# The variance of the (posterior) coefficient 0.0
# For feature of segment 14
# The mean of the (posterior) coefficient 0.05783998324821826
# The variance of the (posterior) coefficient 0.0
# For feature of segment 24
# The mean of the (posterior) coefficient 0.04392258773105079
# The variance of the (posterior) coefficient 0.0
# For feature of segment 38
# The mean of the (posterior) coefficient 0.04190255330907448
# The variance of the (posterior) coefficient 0.0
# For feature of segment 56
# The mean of the (posterior) coefficient 0.04119934579598491
# The variance of the (posterior) coefficient 0.0
# For feature of segment 31
# The mean of the (posterior) coefficient 0.03894940118862672
# The variance of the (posterior) coefficient 0.0
# For feature of segment 21
# The mean of the (posterior) coefficient 0.036025147778686734
# The variance of the (posterior) coefficient 0.0
# [('36', 0.13613138893679472), ('34', 0.0665519094667804), ('47', 0.06212260387143467), ('29', 0.06056040233091802), ('14', 0.05783998324821826), ('24', 0.04392258773105079), ('38', 0.04190255330907448), ('56', 0.04119934579598491), ('31', 0.03894940118862672), ('21', 0.036025147778686734), ('15', 0.03478792386023206), ('46', 0.03166601497954862), ('2', 0.031315530740154696), ('30', -0.031141801409802786), ('27', 0.031092885984666863), ('62', 0.03108517010467708), ('3', -0.027903197173744083), ('11', 0.027764737691233627), ('48', 0.02694316113155901), ('25', 0.026875227832423732), ('0', 0.026423902593465404), ('16', 0.026110935259345724), ('9', 0.02213992775898396), ('49', -0.021881963006277098), ('42', -0.020181763095471872), ('10', -0.019963106291896363), ('53', 0.01992610826845323), ('39', 0.01898505118064286), ('59', -0.018589952137951084), ('13', 0.018042128633471356), ('54', -0.017340610935258155), ('41', -0.017093306359399492), ('32', 0.01665884699822384), ('4', 0.016364532451334856), ('44', -0.015329424790753122), ('23', -0.014741954827347314), ('17', 0.014271263279006442), ('58', 0.012828589198924798), ('40', -0.012071397104888042), ('19', 0.011944128277599449), ('33', -0.011121505261886913), ('12', -0.010898180315837275), ('35', 0.01038756380960703), ('55', -0.010283316541029283), ('20', -0.009245379268929193), ('26', -0.008064721973595014), ('22', 0.006963457054838742), ('7', 0.006934910943761671), ('28', -0.006389740858822723), ('18', 0.005795893808309016), ('45', 0.004623384209814947), ('50', -0.004209857505037295), ('6', -0.004170218311499603), ('60', 0.0038252120087049007), ('52', -0.003298633923947514), ('61', 0.003216970235767569), ('57', 0.0031553490744407947), ('37', -0.002745170763036105), ('43', 0.0011550082381248535), ('8', -0.0009166583781417373), ('5', 0.0006991574690445401), ('1', -0.000567449693475303), ('51', 0.0001435446617655744)]

# %% [markdown]
# #### Now let us explain the image _image[0]_ with BayLIME but without any prior information -- i.e. with option _model_regressor='Bay_non_info_prior'_ .
#
# Essentially we use a zero mean vector as prior knowledge with fitted precision parameters.
#
# Note, you will see 1 set of fitted alpha and lambda parameters (cf. the BayLIME paper for the meanings of these two parameters..) that corresponds to the explanations to the top 1 label.

# %%
explanation = explainer.explain_instance(images[0], inet_model.predict,
                                         top_labels=1, hide_color=0, batch_size=10,
                                         num_samples=200,model_regressor='Bay_non_info_prior')
#'non_Bay' 'Bay_non_info_prior' 'Bay_info_prior','BayesianRidge_inf_prior_fit_alpha'
# Out:
# the number of features: 63
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# using Bay_non_info_prior option for model regressor
# Convergence after  11  iterations
# the alpha is 135.04736365125208
# the lambda is 1668.6996862565593
# the regulation term lambda/alpha is 12.356403273194056

# %% [markdown]
# ##### It is worth to note that the fitted alpha and lambda parameters are recorded in a CSV file './posterior_configure.csv'

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
plt.show()

print(explanation.as_list(explanation.top_labels[0]))
# Out:
# For feature of segment 36
# The mean of the (posterior) coefficient 0.08438808482560477
# The variance of the (posterior) coefficient 0.00022974492971589424
# For feature of segment 34
# The mean of the (posterior) coefficient 0.06660629873999604
# The variance of the (posterior) coefficient 0.00021881312092313258
# For feature of segment 29
# The mean of the (posterior) coefficient 0.06653348561599977
# The variance of the (posterior) coefficient 0.00022854334370647457
# For feature of segment 27
# The mean of the (posterior) coefficient 0.032439938830692315
# The variance of the (posterior) coefficient 0.0002341369643034404
# For feature of segment 32
# The mean of the (posterior) coefficient 0.023215450924984598
# The variance of the (posterior) coefficient 0.00021980131152086823
# [('36', 0.08438808482560477), ('34', 0.06660629873999604), ('29', 0.06653348561599977), ('27', 0.032439938830692315), ('32', 0.023215450924984598), ('47', 0.022330575725739443), ('43', 0.02204361077141434), ('12', 0.02117869546804433), ('24', 0.020227107847454726), ('2', 0.01926381665321974), ('50', 0.019040299596503225), ('52', 0.01816430381550813), ('25', 0.01788981299785065), ('56', 0.01628662686701178), ('48', 0.014304625742982361), ('1', 0.013392743983016975), ('17', 0.012169688180928402), ('39', 0.011876515146005004), ('10', 0.011863098311752545), ('60', 0.011541024704930456), ('8', 0.011403184525392894), ('26', 0.011025926356011406), ('33', 0.010671360414748341), ('44', 0.01052356856873217), ('5', 0.010436919939084173), ('55', -0.009262240306852753), ('53', 0.009009077822506796), ('58', 0.008354996033278505), ('3', 0.008305323983719512), ('61', 0.007709080256669026), ('54', 0.006710779572468749), ('11', 0.006680775469369226), ('41', -0.006523055418276804), ('7', -0.006497380391805836), ('57', 0.006196473472531825), ('46', 0.005950103725684774), ('28', 0.005553814278694202), ('62', 0.005491921825691991), ('51', 0.004659662029658129), ('4', 0.004618609247320913), ('15', 0.004474295484560619), ('37', 0.004152735305086983), ('42', 0.003879046674560588), ('0', -0.0037764158223925295), ('22', 0.0031937625709231405), ('14', -0.00317300978806509), ('18', 0.0029202982906189946), ('20', -0.0026059216499770927), ('23', 0.0025723735703886497), ('31', -0.002284247278160889), ('13', 0.002078798007844709), ('21', -0.0014344175024800314), ('38', 0.001201568139776483), ('35', 0.0011923087075751066), ('19', 0.001126093245510669), ('59', 0.0008076651817017343), ('40', 0.0005511165505988681), ('9', -0.0004199959238012441), ('16', 0.0003500321912759791), ('49', -0.0003111315342054803), ('30', -7.840666789254817e-05), ('6', -5.166791805676779e-05), ('45', -4.0580374201961214e-05)]

# %% [markdown]
# #### Now let us explain the top 1 label of the image _image[0]_ with BayLIME and with full prior knowledge -- i.e. with option _model_regressor='Bay_info_prior'_ .
#
# You will see, in this case, we read the alpha and lambda parameters from the CSV file  './configure.csv'. Moreover, after the explanation, we will again write the parameters into the  './posterior_configure.csv' file.

# %%
explanation = explainer.explain_instance(images[0], inet_model.predict,
                                         top_labels=1, hide_color=1, batch_size=10,
                                         num_samples=200,model_regressor='Bay_info_prior')
# Out:
# the number of features: 63
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# using Bay_info_prior option for model regressor
# the alpha is 1.0
# the lambda is 20.0
# the regulation term lambda/alpha is 20.0

# %% [markdown]
# The following code simply reads the values of the alpha and lambda parameters from the CSV file into two variables.

# %%
alpha_var=1
lambda_var=1
with open('./posterior_configure.csv') as csv_file:
    csv_reader=csv.reader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 1:
            alpha_var=float(row[0])
            lambda_var=float(row[1])
        line_count=line_count+1

# %% [markdown]
# Now in the current explanation, only the data has spoken for themselves (i.e. the second term in the eq. (15) in the BayLIME paper), while the priors knowledge hasn't been combined in (the first term in the eq. (15) in the BayLIMe paper). Now let us combine the prior knowledge (a prior mean vector for all features) that stored in the file '.\data\prior_knowledge_5_jpg.csv'

# %%
explanation=calculate_posteriors.get_posterior(explanation,'.\data\prior_knowledge_5_jpg.csv',
                                               hyper_para_alpha=alpha_var,
                                               hyper_para_lambda=lambda_var,
                                               label=explanation.top_labels[0])

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
plt.show()

print(explanation.as_list(explanation.top_labels[0]))
# Out:
# For feature of segment 36
# The mean of the (posterior) coefficient 0.15246474225451717
# The variance of the (posterior) coefficient 0.02408418395591072
# For feature of segment 34
# The mean of the (posterior) coefficient 0.14783108926845018
# The variance of the (posterior) coefficient 0.024583509808251965
# For feature of segment 29
# The mean of the (posterior) coefficient 0.09335998406318818
# The variance of the (posterior) coefficient 0.024301570249195957
# For feature of segment 32
# The mean of the (posterior) coefficient 0.03664087740366767
# The variance of the (posterior) coefficient 0.02455739937609882
# For feature of segment 47
# The mean of the (posterior) coefficient 0.028071496714291676
# The variance of the (posterior) coefficient 0.024231276788560883
# [('36', 0.15246474225451717), ('34', 0.14783108926845018), ('29', 0.09335998406318818), ('32', 0.03664087740366767), ('47', 0.028071496714291676), ('52', 0.023529261229593625), ('27', 0.022402508839448644), ('60', 0.02072460364851668), ('45', 0.017956197173449172), ('35', 0.017838605291337854), ('15', -0.016412648713942553), ('54', 0.01555098004444564), ('31', 0.01447634812236022), ('14', 0.01443988366285642), ('41', 0.014021055417654523), ('53', 0.013489885526611893), ('50', 0.012951623754889261), ('55', 0.012557421040272718), ('48', 0.012551658118694676), ('18', 0.012275049972118462), ('37', 0.012172443633312328), ('24', 0.012154196787694747), ('23', 0.011498147913444511), ('7', -0.011454219205179889), ('25', 0.010518227327983446), ('33', 0.010449675944701472), ('39', -0.010265626325613215), ('6', -0.009702678755591202), ('17', 0.009559249131536014), ('28', 0.009425013026605887), ('38', 0.00911307224007881), ('10', 0.008677237479156205), ('20', -0.007792709914865048), ('61', 0.007703790365706599), ('21', -0.007509201888462696), ('1', 0.007480762675140883), ('5', 0.007435300931870272), ('51', 0.006705160967013675), ('46', -0.006625289240079558), ('57', -0.006555463397015618), ('13', 0.006063770214493898), ('4', 0.005511901662705902), ('58', 0.004921715173427543), ('12', 0.004866945104421059), ('40', -0.004763656962970869), ('22', 0.0046968657195996305), ('0', 0.004626984783554626), ('8', 0.004608637968222988), ('43', 0.00459255415446457), ('30', 0.004426369245016939), ('62', -0.0043513958114162355), ('2', 0.003725219853466582), ('16', 0.0030516256926829263), ('44', 0.0029995276164311415), ('11', 0.0027840011998944026), ('3', 0.0016364900325077185), ('26', -0.0014706170540925675), ('19', -0.001136347272713043), ('49', -0.0009089104704227097), ('59', -0.0007290339543564386), ('9', 0.0005114974228074489), ('56', -0.00010997664410677239), ('42', -3.9408061226391144e-05)]

# %% [markdown]
# #### Finally, we explain the top 1 label of the image _image[0]_ with BayLIME and with *partial* prior knowledge -- i.e. with option _model_regressor='BayesianRidge_inf_prior_fit_alpha'_ .
#
# You will see, in this case, we fit the alpha from data and read the lambda parameter from the CSV file  './configure.csv'. Then, after the explanation, we will again write both the alpha and lambda parameters into the  './posterior_configure.csv' file.

# %%
explanation = explainer.explain_instance(images[0], inet_model.predict,
                                         top_labels=1, hide_color=0, batch_size=10,
                                         num_samples=200,model_regressor='BayesianRidge_inf_prior_fit_alpha')
#'non_Bay' 'Bay_non_info_prior' 'Bay_info_prior','BayesianRidge_inf_prior_fit_alpha'
# Out:
# the number of features: 63
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# using Bay_info_prior_fixed_lambda_fit_alpha option for model regressor
# Convergence after  2  iterations
# the alpha is 121.9065089510451
# the lambda is 20.0
# the regulation term lambda/alpha is 0.1640601488147901

# %% [markdown]
# The rest of the steps are the same as before (i.e. the case using the full prior knowledge...)

# %%
alpha_var=1
lambda_var=1
with open('./posterior_configure.csv') as csv_file:
    csv_reader=csv.reader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 1:
            alpha_var=float(row[0])
            lambda_var=float(row[1])
        line_count=line_count+1

# %%
explanation=calculate_posteriors.get_posterior(explanation,'.\data\prior_knowledge_5_jpg.csv',
                                               hyper_para_alpha=alpha_var,
                                               hyper_para_lambda=lambda_var,
                                               label=explanation.top_labels[0])

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
plt.show()

print(explanation.as_list(explanation.top_labels[0]))
# Out:
# For feature of segment 36
# The mean of the (posterior) coefficient 0.12991919437477129
# The variance of the (posterior) coefficient 0.00041858952650076164
# For feature of segment 34
# The mean of the (posterior) coefficient 0.0804492913156614
# The variance of the (posterior) coefficient 0.00043632174163300575
# For feature of segment 29
# The mean of the (posterior) coefficient 0.07892666112878095
# The variance of the (posterior) coefficient 0.0005259879804954723
# For feature of segment 1
# The mean of the (posterior) coefficient 0.05650252336297035
# The variance of the (posterior) coefficient 0.0004578116344387738
# For feature of segment 44
# The mean of the (posterior) coefficient 0.04722734705243584
# The variance of the (posterior) coefficient 0.00045400000159323014
# [('36', 0.12991919437477129), ('34', 0.0804492913156614), ('29', 0.07892666112878095), ('1', 0.05650252336297035), ('44', 0.04722734705243584), ('5', 0.04314412738463107), ('48', 0.04248346161550359), ('27', 0.03920736638027297), ('18', 0.03578282908887899), ('33', 0.03534928467696767), ('57', 0.03460656642840182), ('23', 0.03402382852028821), ('40', -0.029593369697487867), ('26', 0.02855450854372994), ('3', -0.027362128605240656), ('43', -0.02698787621680378), ('45', 0.026929171493003837), ('10', 0.025763316543760417), ('53', 0.02492633463529758), ('47', 0.0230231910687884), ('7', 0.022859840330569196), ('25', 0.021884344328288948), ('46', -0.021240153477133338), ('38', 0.01992706139592842), ('19', -0.019646656023719056), ('37', 0.01942842001362499), ('21', -0.01934700530112928), ('52', 0.0186101663202475), ('50', 0.016830528024032756), ('56', -0.01681527994661932), ('2', 0.013335603234348807), ('59', 0.013229359451748142), ('62', -0.01319717762076485), ('12', 0.012779609447640582), ('39', 0.012138109969724118), ('4', 0.011437874433329893), ('0', -0.010993998827449945), ('8', -0.00961211379158334), ('13', -0.00958950975526704), ('20', -0.009468906051360224), ('60', 0.009462053956345173), ('58', 0.009407379908544011), ('54', 0.009229963066227526), ('17', 0.009152202367021623), ('51', 0.009063171028572509), ('14', 0.008899138026445574), ('35', -0.008544744993842236), ('24', 0.008486916858590633), ('32', 0.008082263078248471), ('31', 0.006796582431368633), ('55', 0.005996939847018304), ('11', -0.005177419999752757), ('22', -0.005171430461621935), ('61', 0.004946352631396163), ('41', -0.004863158052386478), ('15', 0.004487997339427746), ('6', -0.0037320683702306294), ('42', -0.00316338672694324), ('49', -0.0029684515839654324), ('28', -0.0024751963297649816), ('30', -0.0022941436642365514), ('9', -0.0005369159631302196), ('16', -0.0005059469625541264)]
